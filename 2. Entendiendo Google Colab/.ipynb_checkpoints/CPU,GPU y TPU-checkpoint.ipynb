# %% [markdown]
# # ¿De que va a estar hecho el cerebro de Skynet?
#
# ## [Soundtrack recomendado para la lectura de este documento](https://open.spotify.com/playlist/3gmpLUPjxqgEAyeT793OpE?si=Yk2W6NMUQb-WKZHdq6K47w)  🎶 🎵 💥
#
# ### El documento contiene link a las citaciones hechas, para aquellos que quieran indagar mas. 😀
#
# <img src="https://mspoweruser.com/wp-content/uploads/2018/06/T-800CPU.jpg" style="width:500px;height:250;">

# %% [markdown]
# ### La inteligencia Artificial no es un cuento particularmente nuevo, ya desde hace décadas se ha venido investigando, pero el avance en esta área parecía estancarse durante algunas ventanas de tiempo que duraron muchos años, a estos periodos se les conoció como [Inviernos de la IA](https://es.wikipedia.org/wiki/Invierno_IA).

# %% [markdown]
# <img src="https://miro.medium.com/max/4202/1*mWYZanOv3QUafz0nnhbEWw.png" style="width:1000px;height:250;">

# %% [markdown]
# ### Al mirar en retrospectiva dichos eventos se originaban por diversos factores, pero uno que llama la atención es el hecho de que en dichas épocas se estaba fuertemente limitado por el hardware disponible, lo cual causaba que los proyectos de investigación mas vanguardistas se quedaran cortos en términos de potencia computacional, pero esto no duro para siempre.

# %% [markdown]
# <img src="https://www.newstatesman.com/sites/default/files/styles/cropped_article_image/public/blogs_2015/06/sean-bean.jpg?itok=Ra5wsfXx" style="width:500px;height:250;">

# %% [markdown]
# ### No fue hasta el año 2009 donde Andrew Ng y su equipo hicieron públicos los resultados de su experimentos empíricos donde demostraron el potencial latente de una tecnología que hasta ese momento estaba relegada a los videojuegos y a algunos temas de procesamiento de video, estamos hablando de las  la tarjetas de video o de manera más técnica GPU (graphic processor unit).
#
# <http://robotics.stanford.edu/~ang/papers/icml09-LargeScaleUnsupervisedDeepLearningGPU.pdf>

# %% [markdown]
# ### Esos pedazos de silicio encargados de que podamos disfrutar nuestros juegos favoritos de manera fluida en nuestros computadores ocultaban dentro de si un enorme potencial que hasta el momento fue ignorado, según los resultados del paper citado anteriormente al emplear este tipo de hardware se obtenía que se podían ejecutar de una manera mucho más rápida los cálculos necesarios para los modelos de machine learning, ceca de unas 15 veces mas rápido que con las CPU disponibles en la época (en la actualidad esta diferencia es muchísimo más grande si hablamos de la última generación de GPU). Esta inusitada ventaja a la hora de hacer cálculos computacionales por parte de las GPU se debe a que estas están diseñadas específicamente para realizar muchísimos cálculos de manera PARALELA a diferencia de las CPU que están diseñadas para realizar cálculos de una manera mas secuencial. ¡Pero como ya sabemos que una imagen habla más que mil palabras, y un video aún mejor! Por eso a continuación veremos una muy didáctica manera de entender como funcionan las GPU de mano de NVIDIA (La mayor fabricante de GPU del mundo y una de las empresas punteras en términos de investigación en IA).

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('-P28LKWTzrI', width=800, height=600)

# %% [markdown]
# ### Desde el año 2010 se empezó a ver un interés renovado en la investigación de las tecnologías vinculadas a la Inteligencia Artificial debido a la capacidad de poder ejecutar modelos cada vez mas y mas grandes, esto de la mano con los asombrosos resultados que estos modelos mostraban. Esto inicio una carrera por parte de múltiples empresas la cuales buscaban el mejor hardware para poder ejecutar estos modelos cada vez mas hambrientos de poder computacional, por lo que a continuación se presentan las alternativas disponibles para la ejecución de Inteligencias artificiales:

# %% [markdown]
# >>
# CPU:
# Los procesadores de toda la vida, estos chips han estado con nosotros desde que las computadores llegaron a nuestras vidas, son circuitos de propósito general ya que fueron concebidas para cumplir con un numero muy amplio de labores, por lo que son muy buenas para ejecutar diversos tipos de tareas, son buenas en todo pero no excelentes, por esto mismo su uso para la ejecución de modelos de inteligencia artificial es muy limitado, especialmente para su entrenamiento debido a sus limitaciones técnicas.

# %% [markdown]
# <img src="https://images-na.ssl-images-amazon.com/images/I/71h68eptZwL._AC_SX450_.jpg" style="width:500px;height:250;">

# %% [markdown]
# > >
# GPU:
# Como se vio anteriormente son las predilectas a la hora de ejecutar modelos de inteligencia artificial, pero por ser las predilectas esto no las hace perfectas. Gracias a sus núcleos que están pensados para el procesamiento en paralelo estas piezas de hardware son idóneas para realizar cálculos de manera rápida, cosa que cae muy bien a los modelos de IA. En los últimos años se ha visto que su desarrollo ha sido muy acelerado gracias al interés que han despertado en los últimos años, como sus máximos exponentes tenemos a NVIDIA y AMD, siendo la primera la realmente relevante para temas de IA.

# %% [markdown]
# <img src="https://www.guiahardware.es/wp-content/uploads/2020/09/gpu-chip.jpg" style="width:500px;height:250;">

# %% [markdown]
# >>
# ASIC´s:
# Ya por último están las ASIC´s o circuito Integrado para aplicaciones específicas, dicho en otras palabras son componentes pensados ESPECIFICAMENTE para modelos de Inteligencia Artificial, esto conlleva que sean muchas más eficientes en términos energéticos que las GPU a la hora de ejecutar dichos modelos, esto les da una ventaja abrumadora sobre las otras alternativas, dentro de esta categoría podemos encontrar las TPU´s (Unidades de procesamiento tensorial) las cuales fueron desarrolladas por Google, son las mas conocidas, pero no son las únicas, otros fabricantes como Intel tienen sus manos metidas en el diseño y fabricación de estos chips, por lo que se esta viendo una carrera un tanto secreta de quien es el que logra la superioridad tecnológica en este aspecto.

# %% [markdown]
# <img src="https://www.ciobulletin.com/assets/home_image/ciobulletin-google-tpu-s-publicly-available.jpg" style="width:500px;height:250;">

# %% [markdown]
# ### Para resumir, se van a enlistar las principales ventajas y desventajas de los diferentes tipos de hardware disponible.

# %% [markdown]
# | CPU                                                                                                                                                    	| GPU                                                                                                                                                        	| TPU                                                                                                                                                                                                                                                       	|
# |--------------------------------------------------------------------------------------------------------------------------------------------------------	|------------------------------------------------------------------------------------------------------------------------------------------------------------	|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------	|
# | VENTAJAS                                                                                                                                               	|                                                                                                                                                            	|                                                                                                                                                                                                                                                           	|
# | CPU-Están presentes en todos los dispositivos desde PC hasta celulares, lo cual les da una ventaja a la hora de la implementación de soluciones en IA. 	| -Son mucho más rápidas que las CPU.                                                                                                                        	| -Al ser componentes pensados específicamente para IA se espera que su costo de fabricación para la venta para el público en general sea reducido, lo cual les daría la ventaja de estar disponibles en cualquier dispositivo para ejecutar modelos de IA. 	|
# |                                                                                                                                                        	| -Tienen soporte para multitud de frameworks de IA como Tensorflow, Pythorch, MXnet, etc.                                                                   	| -Máxima eficiencia energética.                                                                                                                                                                                                                            	|
# |                                                                                                                                                        	| -A pesar de ser componentes algo caros están disponibles para el público en general.                                                                       	|                                                                                                                                                                                                                                                           	|
# |                                                                                                                                                        	| -Su desarrollo esta en auge, además de ser la plataforma predilecta para la IA en estos momentos.                                                          	|                                                                                                                                                                                                                                                           	|
# | DESVENTAJAS                                                                                                                                            	|                                                                                                                                                            	|                                                                                                                                                                                                                                                           	|
# | -Son la alternativa mas lenta.                                                                                                                         	| -A pesar de ser la opción predilecta son relativamente poco eficientes energéticamente lo cual se convierte en un problema para su implementación en masa. 	| -Son relativamente cerradas al desarrollo, en el caso de las TPU solo pueden ejecutar modelos hechos en Tensorflow.                                                                                                                                       	|
# |                                                                                                                                                        	|                                                                                                                                                            	| -Aún no están disponibles para el publico en general, y hasta el momento su coste es elevado.                                                                                                                                                             	|

# %% [markdown]
# ## MATERIAL RECOMENDADO PARA PROFUNDIZAR EN EL TEMA:

# %%
YouTubeVideo('owe9cPEdm7k', width=800, height=600)

# %% [markdown]
# https://blog.inten.to/hardware-for-deep-learning-current-state-and-trends-51c01ebbb6dc

# %% [markdown]
# ## Muchas gracias por su atención!

# %% [markdown]
# ### Autor: Cristian H. Cristancho
